# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("movies.csv")

# %%
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  Star Wars: Episode VII - The Force Awakens (2015)
# 1             1                           Avengers: Endgame (2019)
# 2             2                                      Avatar (2009)
# 3             3                               Black Panther (2018)
# 4             4                      Avengers: Infinity War (2018)
# ..          ...                                                ...
# 913         913                                The Notebook (2004)
# 914         914                   Jimmy Neutron: Boy Genius (2001)
# 915         915                               Eat Pray Love (2010)
# 916         916                 The Texas Chainsaw Massacre (2003)
# 917         917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Movie Info', 'Distributor', 'Release Date',
#        'Domestic Sales (in $)', 'International Sales (in $)',
#        'World Sales (in $)', 'Genre', 'Movie Runtime', 'License'],
#       dtype='object')

# %%
# To do list

# Get rid of unamed column
# --> Done


# Convert Relase Date to Date-Time format


# Convert World Sales
# Reformat Genre
# Investigate License
    
df['Release Date'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# Title                         object
# Movie Info                    object
# Distributor                   object
# Release Date                  object
# Domestic Sales (in $)          int64
# International Sales (in $)     int64
# World Sales (in $)             int64
# Genre                         object
# Movie Runtime                 object
# License                       object
# dtype: object

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 3                                 Black Panther (2018)
# 4                        Avengers: Infinity War (2018)
# ..                                                 ...
# 913                                The Notebook (2004)
# 914                   Jimmy Neutron: Boy Genius (2001)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# 3    T'Challa, heir to the hidden but advanced king...
# ...

# %%
df['Release Date'].isnull().sum()

(118/918)*100 # percent of nulls of total in release date
# Out:
# 12.854030501089325

# %%
df.loc[df['Release Date'].isnull()]
# Out:
#                               Title  \
# 3              Black Panther (2018)
# 4     Avengers: Infinity War (2018)
# 5    Spider-Man: No Way Home (2021)
# 10             Incredibles 2 (2018)
# 16              Finding Dory (2016)
# ..                              ...
# 890   Cheaper by the Dozen 2 (2005)
# 891       Mr. Holland's Opus (1995)
# 896     Bridge to Terabithia (2007)
# 903                     MASH (1970)
# 912                    Congo (1995)
#
#                                             Movie Info  \
# 3    T'Challa, heir to the hidden but advanced king...
# 4    The Avengers and their allies must be willing ...
# 5    With Spider-Man's identity now revealed, Peter...
# 10   The Incredibles family takes on a new mission ...
# 16   Friendly but forgetful blue tang Dory begins a...
# ..                                                 ...
# 890  The Bakers, while on vacation, find themselves...
# 891  A frustrated composer finds fulfillment as a h...
# ...

# %%
test_clean = df.loc[df['Release Date'].isnull()]
test_clean # All of the rows with a null value in Release Date
# Out:
#                               Title  \
# 3              Black Panther (2018)
# 4     Avengers: Infinity War (2018)
# 5    Spider-Man: No Way Home (2021)
# 10             Incredibles 2 (2018)
# 16              Finding Dory (2016)
# ..                              ...
# 890   Cheaper by the Dozen 2 (2005)
# 891       Mr. Holland's Opus (1995)
# 896     Bridge to Terabithia (2007)
# 903                     MASH (1970)
# 912                    Congo (1995)
#
#                                             Movie Info  \
# 3    T'Challa, heir to the hidden but advanced king...
# 4    The Avengers and their allies must be willing ...
# 5    With Spider-Man's identity now revealed, Peter...
# 10   The Incredibles family takes on a new mission ...
# 16   Friendly but forgetful blue tang Dory begins a...
# ..                                                 ...
# 890  The Bakers, while on vacation, find themselves...
# 891  A frustrated composer finds fulfillment as a h...
# ...

# %%
test_clean['Title']
# Out:
# 3                Black Panther (2018)
# 4       Avengers: Infinity War (2018)
# 5      Spider-Man: No Way Home (2021)
# 10               Incredibles 2 (2018)
# 16                Finding Dory (2016)
#                     ...
# 890     Cheaper by the Dozen 2 (2005)
# 891         Mr. Holland's Opus (1995)
# 896       Bridge to Terabithia (2007)
# 903                       MASH (1970)
# 912                      Congo (1995)
# Name: Title, Length: 118, dtype: object

# %%
df.loc[df['Release Date'].isnull(),['Release Date','Title']]
# Out:
#     Release Date                           Title
# 3            NaN            Black Panther (2018)
# 4            NaN   Avengers: Infinity War (2018)
# 5            NaN  Spider-Man: No Way Home (2021)
# 10           NaN            Incredibles 2 (2018)
# 16           NaN             Finding Dory (2016)
# ..           ...                             ...
# 890          NaN   Cheaper by the Dozen 2 (2005)
# 891          NaN       Mr. Holland's Opus (1995)
# 896          NaN     Bridge to Terabithia (2007)
# 903          NaN                     MASH (1970)
# 912          NaN                    Congo (1995)
#
# [118 rows x 2 columns]

# %%
test_arr = np.array([i for i in range(0,len(test_clean['Title']))])

# %%
test_clean = df.loc[df['Release Date'].isnull()]

test_arr = np.array([i for i in range(0,len(test_clean['Title']))])

for index,i in enumerate(test_clean['Title']):
    test_arr[index] = i[-5:-1]
    


df.rename(columns={"Release Date":"Release_Date"})
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 3                                 Black Panther (2018)
# 4                        Avengers: Infinity War (2018)
# ..                                                 ...
# 913                                The Notebook (2004)
# 914                   Jimmy Neutron: Boy Genius (2001)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# 3    T'Challa, heir to the hidden but advanced king...
# ...

# %%
df.loc[df.col_name.isnull(), 'col_name'] = test_arr

# This is how you fill a Column with Null Values with a generated list.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-81ac3eaa29ae> in <module>
# ----> 1 df.Release
#
# c:\users\axlcr\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5581         ):
#    5582             return self[name]
# -> 5583         return object.__getattribute__(self, name)
#    5584
#    5585     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Release'

# %%
new_list = []

# %%
z = 0

for i in df['Release Date']:
    if type(i) == float:
        new_list.append(test_arr[z])
        z+=1
    else:
        new_list.append(i)

# %%
new_list
# Out:
# ['December 16, 2015',
#  'April 24, 2019',
#  'December 16, 2009',
#  2018,
#  2018,
#  2021,
#  'December 19, 1997',
#  'June 10, 2015',
#  'April 25, 2012',
#  'December 13, 2017',
#  2018,
#  'July 11, 2019',
#  'July 16, 2008',
#  'December 14, 2016',
#  'December 18, 2019',
#  'March 16, 2017',
#  2016,
#  'November 20, 2019',
#  'May 19, 1999',
#  'May 25, 1977',
#  'April 22, 2015',
#  'July 19, 2012',
#  'May 19, 2004',
#  'June 11, 1982',
#  'June 20, 2019',
#  'March 6, 2019',
#  'November 15, 2013',
#  'July 6, 2006',
#  'June 15, 1994',
#  'June 6, 2018',
#  'June 16, 2010',
#  'May 30, 2017',
#  'April 24, 2013',
#  'April 27, 2016',
#  'March 8, 2012',
#  'May 3, 2002',
#  'December 20, 2017',
#  'June 11, 1993',
#  'June 19, 2009',
#  'November 22, 2013',
#  'June 28, 2019',
#  'April 25, 2017',
#  2011,
#  'May 30, 2003',
#  'May 18, 2005',
#  'December 17, 2003',
#  'June 30, 2004',
#  'February 25, 2004',
#  'June 24, 2016',
#  'June 20, 2013',
#  'April 7, 2016',
# ...

# %%
df['Release Date'] = new_list

# %%
df
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 3                                 Black Panther (2018)
# 4                        Avengers: Infinity War (2018)
# ..                                                 ...
# 913                                The Notebook (2004)
# 914                   Jimmy Neutron: Boy Genius (2001)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# 3    T'Challa, heir to the hidden but advanced king...
# ...

# %%
    
test_arr
# Out:
# array([2018, 2018, 2021, 2018, 2016, 2011, 2016, 2018, 2012, 2010, 2013,
#        2013, 2014, 2006, 2016, 1973, 2017, 2021, 2007, 2018, 2021, 2017,
#        2014, 2005, 2011, 1937, 1993, 2021, 1997, 2017, 1995, 1992, 2021,
#        2007, 2021, 2021, 2020, 1993, 2006, 2017, 2015, 1989, 1998, 2008,
#        1995, 1998, 1992, 1997, 1996, 2017, 1985, 1998, 1997, 2021, 2000,
#        1996, 2015, 1992, 2021, 2007, 2007, 2021, 2021, 1986, 1996, 1995,
#        2021, 1993, 1995, 2003, 1996, 1996, 2006, 1994, 1992, 1993, 2021,
#        2018, 1995, 2007, 1996, 2008, 1977, 2009, 1955, 1997, 2021, 1994,
#        2017, 1996, 1995, 2014, 2001, 2007, 2009, 1996, 2005, 1992, 1953,
#        2012, 2021, 2015, 2011, 1981, 1986, 1995, 2006, 2004, 1998, 1992,
#        1979, 2018, 2011, 2005, 1995, 2007, 1970, 1995])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-181329c39c0f> in <module>
# ----> 1 df.loc[df['Release Date'].isnull()] = test_arr
#
# c:\users\axlcr\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# c:\users\axlcr\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1686         if take_split_path:
#    1687             # We have to operate column-wise
# -> 1688             self._setitem_with_indexer_split_path(indexer, value, name)
#    1689         else:
# ...
