# %% [markdown]
# # Data and How To Source It

# %% [markdown]
# # What is an API?

# %% [markdown]
# API stands for Application Programming Interface

# %% [markdown]
# # How do we make HTTPS requests in Python

# %%
import requests

# %%
# Issues a get request to the API Endpoint
r = requests.get('https://api.github.com/events')

# %%
#Attribute that gets me the raw text as a string
r.text

# %%
r.json()[0]

# %%
# It's as simple as that. Sometimes, the encoding isn't right. Requests tries to infer
# What encoding to use, so you can change it manually with
# r.encoding = 'encoding_to_use'
# We can see that the returned object is what we are operating on.
#UTF-8

# %% [markdown]
# # Let's work through an example

# %%
r = requests.get('https://data.cityofnewyork.us/resource/f9bf-2cp4.json')

# %%
r.text

# %%
r.json()

# %%
import pandas as pd

# %%
df = pd.read_json(r.text)

# %%
df

# %%
payload = {'$limit':10,"$$app_token":"tq19sOJfOJFRot5OrORkOEbsS"}
r = requests.get('https://data.cityofnewyork.us/resource/f9bf-2cp4.json', params=payload)

# %%
r.text

# %%
r.json()

# %%
test = pd.read_json(r.text)
test

# %%
test.boxplot(column='sat_critical_reading_avg_score')

# %%
# form a get to grab the websites HTML
r = requests.get('https://basketball-reference.com/teams/PHI/2022.html')

# %%
from bs4 import BeautifulSoup

# %%
# turn the raw HTML into a soup object
soup = BeautifulSoup(r.text,'html.parser')

# %%
#One way of finding the table that contains the data
earnest_attempt = soup.findAll('div',attrs={'id':'div_roster'})

# %%
#Another way of finding the table that contains the data.
found_table = soup.findAll('table')

# %%
#I know the roster table is the first table that appears, so I'm grabbing it
roster_table = found_table[0]

# %%
#Grab all the table rows from the table.
player_rows = roster_table('tr')

# %%
player_rows

# %%
#I know that I don't need the first row, so I'm deleting it
del player_rows[0]

# %%
player_rows

# %%
#I am selecting all the Table Data from the first row
player_rows[0].find_all('td')

# %%
#List comprehension to extract all the text data from each TD element.
extracted_text = [ele.text for ele in player_rows[0].find_all('td') ]

# %%
extracted_text

# %%
#This is going to serve as the keys in my k,v pairings
keys = ['Player_Name','Position','Height','Weight','DOB','COB','Experience','Alma_Matter']

# %%
#initialize a dict to hold the result of my for loop
player_dict = []


#Iterate over the list of rows in my table
#apply the same logic as before.
#Locate all the td elements
#extract all the text from the td elements
#zip them with my keys
for player in player_rows:
    found_rows = player.find_all('td')
    stripped_text = [ele.text for ele in found_rows]
    player_dict.append(dict(zip(keys,stripped_text)))

# %%
player_dict
# Out:
# [{'Player_Name': 'Georges Niang',
#   'Position': 'PF',
#   'Height': '6-7',
#   'Weight': '230',
#   'DOB': 'June 17, 1993',
#   'COB': 'us',
#   'Experience': '5',
#   'Alma_Matter': 'Iowa State'},
#  {'Player_Name': 'Tyrese Maxey',
#   'Position': 'PG',
#   'Height': '6-2',
#   'Weight': '200',
#   'DOB': 'November 4, 2000',
#   'COB': 'us',
#   'Experience': '1',
#   'Alma_Matter': 'Kentucky'},
#  {'Player_Name': 'Tobias Harris',
#   'Position': 'PF',
#   'Height': '6-8',
#   'Weight': '226',
#   'DOB': 'July 15, 1992',
#   'COB': 'us',
#   'Experience': '10',
#   'Alma_Matter': 'Tennessee'},
#  {'Player_Name': 'Joel Embiid',
#   'Position': 'C',
#   'Height': '7-0',
#   'Weight': '280',
#   'DOB': 'March 16, 1994',
#   'COB': 'cm',
#   'Experience': '5',
#   'Alma_Matter': 'Kansas'},
#  {'Player_Name': 'Furkan Korkmaz',
#   'Position': 'SG',
#   'Height': '6-7',
#   'Weight': '202',
#   'DOB': 'July 24, 1997',
#   'COB': 'tr',
#   'Experience': '4',
#   'Alma_Matter': ''},
#  {'Player_Name': 'Matisse Thybulle',
#   'Position': 'SG',
#   'Height': '6-5',
#   'Weight': '201',
#   'DOB': 'March 4, 1997',
#   'COB': 'us',
#   'Experience': '2',
#   'Alma_Matter': 'Washington'},
#  {'Player_Name': 'Danny Green',
#   'Position': 'SF',
#   'Height': '6-6',
#   'Weight': '215',
#   'DOB': 'June 22, 1987',
#   'COB': 'us',
#   'Experience': '12',
#   'Alma_Matter': 'UNC'},
#  {'Player_Name': 'Isaiah Joe',
#   'Position': 'SG',
#   'Height': '6-4',
#   'Weight': '165',
#   'DOB': 'July 2, 1999',
#   'COB': 'us',
#   'Experience': '1',
#   'Alma_Matter': 'Arkansas'},
#  {'Player_Name': 'Shake Milton',
#   'Position': 'PG',
#   'Height': '6-5',
#   'Weight': '205',
#   'DOB': 'September 26, 1996',
#   'COB': 'us',
#   'Experience': '3',
#   'Alma_Matter': 'SMU'},
#  {'Player_Name': 'Paul Reed',
#   'Position': 'C',
#   'Height': '6-9',
#   'Weight': '210',
#   'DOB': 'June 14, 1999',
#   'COB': 'us',
#   'Experience': '1',
#   'Alma_Matter': 'DePaul'},
#  {'Player_Name': 'Charles Bassey',
#   'Position': 'PF',
#   'Height': '6-11',
#   'Weight': '235',
#   'DOB': 'October 28, 2000',
#   'COB': 'ng',
#   'Experience': 'R',
#   'Alma_Matter': 'Western Kentucky'},
#  {'Player_Name': 'Charlie Brown Jr.',
#   'Position': 'SG',
#   'Height': '6-6',
#   'Weight': '199',
#   'DOB': 'February 2, 1997',
#   'COB': 'us',
#   'Experience': '2',
#   'Alma_Matter': "Saint Joseph's"},
#  {'Player_Name': 'James Harden',
#   'Position': 'SG',
#   'Height': '6-5',
#   'Weight': '220',
#   'DOB': 'August 26, 1989',
#   'COB': 'us',
#   'Experience': '12',
#   'Alma_Matter': 'Arizona State'},
#  {'Player_Name': 'Myles Powell\xa0\xa0(TW)',
#   'Position': 'PG',
#   'Height': '6-2',
#   'Weight': '195',
#   'DOB': 'July 7, 1997',
#   'COB': 'us',
#   'Experience': 'R',
#   'Alma_Matter': 'Seton Hall'},
#  {'Player_Name': 'Paul Millsap',
#   'Position': 'PF',
#   'Height': '6-7',
#   'Weight': '257',
#   'DOB': 'February 10, 1985',
#   'COB': 'us',
#   'Experience': '15',
#   'Alma_Matter': 'Louisiana Tech'},
#  {'Player_Name': 'DeAndre Jordan',
#   'Position': 'C',
#   'Height': '6-11',
#   'Weight': '265',
#   'DOB': 'July 21, 1988',
#   'COB': 'us',
#   'Experience': '13',
#   'Alma_Matter': 'Texas A&M'},
#  {'Player_Name': 'Jaden Springer',
#   'Position': 'SG',
#   'Height': '6-4',
#   'Weight': '204',
#   'DOB': 'September 25, 2002',
#   'COB': 'us',
#   'Experience': 'R',
#   'Alma_Matter': 'Tennessee'}]

# %%
#create a new df from my list of Dicts
df = pd.DataFrame(player_dict)

# %%
df
# Out:
#            Player_Name Position Height Weight                 DOB COB  \
# 0        Georges Niang       PF    6-7    230       June 17, 1993  us
# 1         Tyrese Maxey       PG    6-2    200    November 4, 2000  us
# 2        Tobias Harris       PF    6-8    226       July 15, 1992  us
# 3          Joel Embiid        C    7-0    280      March 16, 1994  cm
# 4       Furkan Korkmaz       SG    6-7    202       July 24, 1997  tr
# 5     Matisse Thybulle       SG    6-5    201       March 4, 1997  us
# 6          Danny Green       SF    6-6    215       June 22, 1987  us
# 7           Isaiah Joe       SG    6-4    165        July 2, 1999  us
# 8         Shake Milton       PG    6-5    205  September 26, 1996  us
# 9            Paul Reed        C    6-9    210       June 14, 1999  us
# 10      Charles Bassey       PF   6-11    235    October 28, 2000  ng
# 11   Charlie Brown Jr.       SG    6-6    199    February 2, 1997  us
# 12        James Harden       SG    6-5    220     August 26, 1989  us
# 13  Myles Powell  (TW)       PG    6-2    195        July 7, 1997  us
# 14        Paul Millsap       PF    6-7    257   February 10, 1985  us
# 15      DeAndre Jordan        C   6-11    265       July 21, 1988  us
# 16      Jaden Springer       SG    6-4    204  September 25, 2002  us
#
#    Experience       Alma_Matter
# 0           5        Iowa State
# 1           1          Kentucky
# 2          10         Tennessee
# 3           5            Kansas
# 4           4
# 5           2        Washington
# 6          12               UNC
# 7           1          Arkansas
# 8           3               SMU
# 9           1            DePaul
# 10          R  Western Kentucky
# 11          2    Saint Joseph's
# 12         12     Arizona State
# 13          R        Seton Hall
# 14         15    Louisiana Tech
# 15         13         Texas A&M
# 16          R         Tennessee

# %%
#Method number 2 using lists
player_dict = []
for player in player_rows:
    found_rows = player.find_all('td')
    stripped_text = [ele.text for ele in found_rows]
    player_dict.append(stripped_text)

# %%
#Initialize my DF using list of lists
df = pd.DataFrame(player_dict,columns=['Player_Name','Position','Height','Weight','DOB','COB','Experience','Alma_Matter'])

# %%
df
# Out:
#            Player_Name Position Height Weight                 DOB COB  \
# 0        Georges Niang       PF    6-7    230       June 17, 1993  us
# 1         Tyrese Maxey       PG    6-2    200    November 4, 2000  us
# 2        Tobias Harris       PF    6-8    226       July 15, 1992  us
# 3          Joel Embiid        C    7-0    280      March 16, 1994  cm
# 4       Furkan Korkmaz       SG    6-7    202       July 24, 1997  tr
# 5     Matisse Thybulle       SG    6-5    201       March 4, 1997  us
# 6          Danny Green       SF    6-6    215       June 22, 1987  us
# 7           Isaiah Joe       SG    6-4    165        July 2, 1999  us
# 8         Shake Milton       PG    6-5    205  September 26, 1996  us
# 9            Paul Reed        C    6-9    210       June 14, 1999  us
# 10      Charles Bassey       PF   6-11    235    October 28, 2000  ng
# 11   Charlie Brown Jr.       SG    6-6    199    February 2, 1997  us
# 12        James Harden       SG    6-5    220     August 26, 1989  us
# 13  Myles Powell  (TW)       PG    6-2    195        July 7, 1997  us
# 14        Paul Millsap       PF    6-7    257   February 10, 1985  us
# 15      DeAndre Jordan        C   6-11    265       July 21, 1988  us
# 16      Jaden Springer       SG    6-4    204  September 25, 2002  us
#
#    Experience       Alma_Matter
# 0           5        Iowa State
# 1           1          Kentucky
# 2          10         Tennessee
# 3           5            Kansas
# 4           4
# 5           2        Washington
# 6          12               UNC
# 7           1          Arkansas
# 8           3               SMU
# 9           1            DePaul
# 10          R  Western Kentucky
# 11          2    Saint Joseph's
# 12         12     Arizona State
# 13          R        Seton Hall
# 14         15    Louisiana Tech
# 15         13         Texas A&M
# 16          R         Tennessee

# %%
soup.findAll('table')
# Out:
# [<table class="sortable stats_table" data-cols-to-freeze=",2" id="roster">
#  <caption>Roster Table</caption>
#  <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
#  <thead>
#  <tr>
#  <th aria-label="No." class="poptip sort_default_asc center" data-stat="number" data-tip="Uniform Number" scope="col">No.</th>
#  <th aria-label="Player" class="poptip sort_default_asc center" data-stat="player" scope="col">Player</th>
#  <th aria-label="Pos" class="poptip sort_default_asc center" data-stat="pos" data-tip="Position" scope="col">Pos</th>
#  <th aria-label="Ht" class="poptip sort_default_asc center" data-stat="height" data-tip="Height" scope="col">Ht</th>
#  <th aria-label="Wt" class="poptip sort_default_asc center" data-stat="weight" data-tip="Weight" scope="col">Wt</th>
#  <th aria-label="Birth Date" class="poptip sort_default_asc center" data-stat="birth_date" scope="col">Birth Date</th>
#  <th aria-label=" " class="poptip center" data-stat="birth_country" scope="col"> </th>
#  <th aria-label="Exp" class="poptip sort_default_asc center" data-stat="years_experience" data-tip="Years experience in NBA/ABA (prior to this season)" scope="col">Exp</th>
#  <th aria-label="College" class="poptip sort_default_asc center" data-stat="college" scope="col">College</th>
#  </tr>
#  </thead>
#  <tbody><tr><th class="center" data-stat="number" scope="row">20</th><td class="left" csk="Niang,Georges" data-stat="player"><a href="/players/n/niangge01.html">Georges Niang</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">230</td><td class="left" csk="19930617" data-stat="birth_date">June 17, 1993</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="5" data-stat="years_experience">5</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=iowast">Iowa State</a></td></tr>
#  <tr><th class="center iz" data-stat="number" scope="row">0</th><td class="left" csk="Maxey,Tyrese" data-stat="player"><a href="/players/m/maxeyty01.html">Tyrese Maxey</a></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="74.0" data-stat="height">6-2</td><td class="right" data-stat="weight">200</td><td class="left" csk="20001104" data-stat="birth_date">November 4, 2000</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=kentucky">Kentucky</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">12</th><td class="left" csk="Harris,Tobias" data-stat="player"><a href="/players/h/harrito02.html">Tobias Harris</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="80.0" data-stat="height">6-8</td><td class="right" data-stat="weight">226</td><td class="left" csk="19920715" data-stat="birth_date">July 15, 1992</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="10" data-stat="years_experience">10</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">21</th><td class="left" csk="Embiid,Joel" data-stat="player"><a href="/players/e/embiijo01.html">Joel Embiid</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="84.0" data-stat="height">7-0</td><td class="right" data-stat="weight">280</td><td class="left" csk="19940316" data-stat="birth_date">March 16, 1994</td><td class="right" data-stat="birth_country"><span class="f-i f-cm" style="">cm</span></td><td class="right" csk="5" data-stat="years_experience">5</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=kansas">Kansas</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">30</th><td class="left" csk="Korkmaz,Furkan" data-stat="player"><a href="/players/k/korkmfu01.html">Furkan Korkmaz</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">202</td><td class="left" csk="19970724" data-stat="birth_date">July 24, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-tr" style="">tr</span></td><td class="right" csk="4" data-stat="years_experience">4</td><td class="left iz" data-stat="college"></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">22</th><td class="left" csk="Thybulle,Matisse" data-stat="player"><a href="/players/t/thybuma01.html">Matisse Thybulle</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">201</td><td class="left" csk="19970304" data-stat="birth_date">March 4, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="2" data-stat="years_experience">2</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=washington">Washington</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">14</th><td class="left" csk="Green,Danny" data-stat="player"><a href="/players/g/greenda02.html">Danny Green</a></td><td class="center" csk="3" data-stat="pos">SF</td><td class="right" csk="78.0" data-stat="height">6-6</td><td class="right" data-stat="weight">215</td><td class="left" csk="19870622" data-stat="birth_date">June 22, 1987</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="12" data-stat="years_experience">12</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=unc">UNC</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">7</th><td class="left" csk="Joe,Isaiah" data-stat="player"><a href="/players/j/joeis01.html">Isaiah Joe</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="76.0" data-stat="height">6-4</td><td class="right" data-stat="weight">165</td><td class="left" csk="19990702" data-stat="birth_date">July 2, 1999</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=arkansas">Arkansas</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">18</th><td class="left" csk="Milton,Shake" data-stat="player"><a href="/players/m/miltosh01.html">Shake Milton</a></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">205</td><td class="left" csk="19960926" data-stat="birth_date">September 26, 1996</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="3" data-stat="years_experience">3</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=smethodist">SMU</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">44</th><td class="left" csk="Reed,Paul" data-stat="player"><a href="/players/r/reedpa01.html">Paul Reed</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="81.0" data-stat="height">6-9</td><td class="right" data-stat="weight">210</td><td class="left" csk="19990614" data-stat="birth_date">June 14, 1999</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="1" data-stat="years_experience">1</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=depaul">DePaul</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">23</th><td class="left" csk="Bassey,Charles" data-stat="player"><a href="/players/b/bassech01.html">Charles Bassey</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="83.0" data-stat="height">6-11</td><td class="right" data-stat="weight">235</td><td class="left" csk="20001028" data-stat="birth_date">October 28, 2000</td><td class="right" data-stat="birth_country"><span class="f-i f-ng" style="">ng</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=wkentucky">Western Kentucky</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">16</th><td class="left" csk="Brown,Charlie" data-stat="player"><a href="/players/b/brownch02.html">Charlie Brown Jr.</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="78.0" data-stat="height">6-6</td><td class="right" data-stat="weight">199</td><td class="left" csk="19970202" data-stat="birth_date">February 2, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="2" data-stat="years_experience">2</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=stjosephs">Saint Joseph's</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">1</th><td class="left" csk="Harden,James" data-stat="player"><a href="/players/h/hardeja01.html">James Harden</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="77.0" data-stat="height">6-5</td><td class="right" data-stat="weight">220</td><td class="left" csk="19890826" data-stat="birth_date">August 26, 1989</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="12" data-stat="years_experience">12</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=arizonast">Arizona State</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">5</th><td class="left" csk="Powell,Myles" data-stat="player"><a href="/players/p/powelmy01.html">Myles Powell</a>  <span class="note"><small>(TW)</small></span></td><td class="center" csk="1" data-stat="pos">PG</td><td class="right" csk="74.0" data-stat="height">6-2</td><td class="right" data-stat="weight">195</td><td class="left" csk="19970707" data-stat="birth_date">July 7, 1997</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=setonhall">Seton Hall</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">8</th><td class="left" csk="Millsap,Paul" data-stat="player"><a href="/players/m/millspa01.html">Paul Millsap</a></td><td class="center" csk="4" data-stat="pos">PF</td><td class="right" csk="79.0" data-stat="height">6-7</td><td class="right" data-stat="weight">257</td><td class="left" csk="19850210" data-stat="birth_date">February 10, 1985</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="15" data-stat="years_experience">15</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=latech">Louisiana Tech</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">9</th><td class="left" csk="Jordan,DeAndre" data-stat="player"><a href="/players/j/jordade01.html">DeAndre Jordan</a></td><td class="center" csk="5" data-stat="pos">C</td><td class="right" csk="83.0" data-stat="height">6-11</td><td class="right" data-stat="weight">265</td><td class="left" csk="19880721" data-stat="birth_date">July 21, 1988</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="13" data-stat="years_experience">13</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=texasam">Texas A&amp;M</a></td></tr>
#  <tr><th class="center" data-stat="number" scope="row">11</th><td class="left" csk="Springer,Jaden" data-stat="player"><a href="/players/s/sprinja01.html">Jaden Springer</a></td><td class="center" csk="2" data-stat="pos">SG</td><td class="right" csk="76.0" data-stat="height">6-4</td><td class="right" data-stat="weight">204</td><td class="left" csk="20020925" data-stat="birth_date">September 25, 2002</td><td class="right" data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right" csk="0.5" data-stat="years_experience">R</td><td class="left" data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>
#  </tbody></table>,
#  <table class="stats_table sortable" data-cols-to-freeze=",2" id="per_game"> <caption>Per Game Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rk" class="ranker poptip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th> <th aria-label=" " class="poptip sort_default_asc center" data-stat="player" scope="col"> </th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Player's age on February 1 of the season" scope="col">Age</th> <th aria-label="Games" class="poptip center" data-stat="g" data-tip="Games" scope="col">G</th> <th aria-label="Games Started" class="poptip center" data-stat="gs" data-tip="Games Started" scope="col">GS</th> <th aria-label="Minutes Played Per Game" class="poptip center" data-stat="mp_per_g" data-tip="Minutes Played Per Game" scope="col">MP</th> <th aria-label="Field Goals Per Game" class="poptip center" data-stat="fg_per_g" data-tip="Field Goals Per Game" scope="col">FG</th> <th aria-label="Field Goal Attempts Per Game" class="poptip center" data-stat="fga_per_g" data-tip="Field Goal Attempts Per Game" scope="col">FGA</th> <th aria-label="Field Goal Percentage" class="poptip center" data-stat="fg_pct" data-tip="Field Goal Percentage" scope="col">FG%</th> <th aria-label="3-Point Field Goals Per Game" class="poptip center" data-stat="fg3_per_g" data-tip="3-Point Field Goals Per Game" scope="col">3P</th> <th aria-label="3-Point Field Goal Attempts Per Game" class="poptip center" data-stat="fg3a_per_g" data-tip="3-Point Field Goal Attempts Per Game" scope="col">3PA</th> <th aria-label="3-Point Field Goal Percentage" class="poptip center" data-stat="fg3_pct" data-tip="3-Point Field Goal Percentage" scope="col">3P%</th> <th aria-label="2-Point Field Goals Per Game" class="poptip center" data-stat="fg2_per_g" data-tip="2-Point Field Goals Per Game" scope="col">2P</th> <th aria-label="2-Point Field Goal Attempts Per Game" class="poptip center" data-stat="fg2a_per_g" data-tip="2-Point Field Goal Attempts Per Game" scope="col">2PA</th> <th aria-label="2-Point Field Goal Percentage" class="poptip center" data-stat="fg2_pct" data-tip="2-Point Field Goal Percentage" scope="col">2P%</th> <th aria-label="Effective Field Goal Percentage" class="poptip center" data-stat="efg_pct" data-tip="&lt;strong&gt;Effective Field Goal Percentage&lt;/strong&gt;&lt;br&gt;This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal." scope="col">eFG%</th> <th aria-label="Free Throws Per Game" class="poptip center" data-stat="ft_per_g" data-tip="Free Throws Per Game" scope="col">FT</th> <th aria-label="Free Throw Attempts Per Game" class="poptip center" data-stat="fta_per_g" data-tip="Free Throw Attempts Per Game" scope="col">FTA</th> <th aria-label="Free Throw Percentage" class="poptip center" data-stat="ft_pct" data-tip="Free Throw Percentage" scope="col">FT%</th> <th aria-label="Offensive Rebounds Per Game" class="poptip center" data-stat="orb_per_g" data-tip="Offensive Rebounds Per Game" scope="col">ORB</th> <th aria-label="Defensive Rebounds Per Game" class="poptip center" data-stat="drb_per_g" data-tip="Defensive Rebounds Per Game" scope="col">DRB</th> <th aria-label="Total Rebounds Per Game" class="poptip center" data-stat="trb_per_g" data-tip="Total Rebounds Per Game" scope="col">TRB</th> <th aria-label="Assists Per Game" class="poptip center" data-stat="ast_per_g" data-tip="Assists Per Game" scope="col">AST</th> <th aria-label="Steals Per Game" class="poptip center" data-stat="stl_per_g" data-tip="Steals Per Game" scope="col">STL</th> <th aria-label="Blocks Per Game" class="poptip center" data-stat="blk_per_g" data-tip="Blocks Per Game" scope="col">BLK</th> <th aria-label="Turnovers Per Game" class="poptip  ...
#  <table class="stats_table sortable" data-cols-to-freeze=",2" id="totals"> <caption>Totals Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rk" class="ranker poptip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th> <th aria-label=" " class="poptip sort_default_asc center" data-stat="player" scope="col"> </th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Player's age on February 1 of the season" scope="col">Age</th> <th aria-label="Games" class="poptip center" data-stat="g" data-tip="Games" scope="col">G</th> <th aria-label="Games Started" class="poptip center" data-stat="gs" data-tip="Games Started" scope="col">GS</th> <th aria-label="Minutes Played" class="poptip center" data-stat="mp" data-tip="Minutes Played" scope="col">MP</th> <th aria-label="Field Goals" class="poptip center" data-stat="fg" data-tip="Field Goals" scope="col">FG</th> <th aria-label="FGA" class="poptip center" data-stat="fga" data-tip="Field Goal Attempts" scope="col">FGA</th> <th aria-label="Field Goal Percentage" class="poptip center" data-stat="fg_pct" data-tip="Field Goal Percentage" scope="col">FG%</th> <th aria-label="3-Point Field Goals" class="poptip center" data-stat="fg3" data-tip="3-Point Field Goals" scope="col">3P</th> <th aria-label="3-Point Field Goal Attempts" class="poptip center" data-stat="fg3a" data-tip="3-Point Field Goal Attempts" scope="col">3PA</th> <th aria-label="3-Point Field Goal Percentage" class="poptip center" data-stat="fg3_pct" data-tip="3-Point Field Goal Percentage" scope="col">3P%</th> <th aria-label="2-Point Field Goals" class="poptip center" data-stat="fg2" data-tip="2-Point Field Goals" scope="col">2P</th> <th aria-label="2-point Field Goal Attempts" class="poptip center" data-stat="fg2a" data-tip="2-point Field Goal Attempts" scope="col">2PA</th> <th aria-label="2-Point Field Goal Percentage" class="poptip center" data-stat="fg2_pct" data-tip="2-Point Field Goal Percentage" scope="col">2P%</th> <th aria-label="Effective Field Goal Percentage" class="poptip center" data-stat="efg_pct" data-tip="&lt;strong&gt;Effective Field Goal Percentage&lt;/strong&gt;&lt;br&gt;This statistic adjusts for the fact that a 3-point field goal is worth one more point than a 2-point field goal." scope="col">eFG%</th> <th aria-label="Free Throws" class="poptip center" data-stat="ft" data-tip="Free Throws" scope="col">FT</th> <th aria-label="Free Throw Attempts" class="poptip center" data-stat="fta" data-tip="Free Throw Attempts" scope="col">FTA</th> <th aria-label="Free Throw Percentage" class="poptip center" data-stat="ft_pct" data-tip="Free Throw Percentage" scope="col">FT%</th> <th aria-label="Offensive Rebounds" class="poptip center" data-stat="orb" data-tip="Offensive Rebounds" scope="col">ORB</th> <th aria-label="Defensive Rebounds" class="poptip center" data-stat="drb" data-tip="Defensive Rebounds" scope="col">DRB</th> <th aria-label="Total Rebounds" class="poptip center" data-stat="trb" data-tip="Total Rebounds" scope="col">TRB</th> <th aria-label="Assists" class="poptip center" data-stat="ast" data-tip="Assists" scope="col">AST</th> <th aria-label="Steals" class="poptip center" data-stat="stl" data-tip="Steals" scope="col">STL</th> <th aria-label="Blocks" class="poptip center" data-stat="blk" data-tip="Blocks" scope="col">BLK</th> <th aria-label="Turnovers" class="poptip center" data-stat="tov" data-tip="Turnovers" scope="col">TOV</th> <th aria-label="Personal Fouls" class="poptip center" data-stat="pf" data-tip="Personal Fouls" scope="col">PF</th> <th aria-label="Points" class="poptip center" data-stat="pts" data-tip="Points" scope="col">PTS</th> </tr> </thead> <tbody> <tr><th class="center" data-stat="ranker" scope="row">1</th><td class="left" csk="Ma ...
#  <table class="stats_table sortable" data-cols-to-freeze=",2" id="advanced"> <caption>Advanced Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rk" class="ranker poptip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th> <th aria-label=" " class="poptip sort_default_asc center" data-stat="player" scope="col"> </th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Player's age on February 1 of the season" scope="col">Age</th> <th aria-label="Games" class="poptip center" data-stat="g" data-tip="Games" scope="col">G</th> <th aria-label="Minutes Played" class="poptip center" data-stat="mp" data-tip="Minutes Played" scope="col">MP</th> <th aria-label="Player Efficiency Rating" class="poptip center" data-stat="per" data-tip="&lt;b&gt;Player Efficiency Rating&lt;/b&gt;&lt;br&gt;A measure of per-minute production standardized such that the league average is 15." scope="col">PER</th> <th aria-label="True Shooting Percentage" class="poptip center" data-stat="ts_pct" data-tip="&lt;strong&gt;True Shooting Percentage&lt;/strong&gt;&lt;br&gt;A measure of shooting efficiency that takes into account 2-point field goals, 3-point field goals, and free throws." scope="col">TS%</th> <th aria-label="3-Point Attempt Rate" class="poptip center" data-stat="fg3a_per_fga_pct" data-tip="&lt;strong&gt;3-Point Attempt Rate&lt;/strong&gt;&lt;br&gt;Percentage of FG Attempts from 3-Point Range" scope="col">3PAr</th> <th aria-label="Free Throw Attempt Rate" class="poptip center" data-stat="fta_per_fga_pct" data-tip="&lt;strong&gt;Free Throw Attempt Rate&lt;/strong&gt;&lt;br&gt;Number of FT Attempts Per FG Attempt" scope="col">FTr</th> <th aria-label="Offensive Rebound Percentage" class="poptip center" data-stat="orb_pct" data-tip="&lt;b&gt;Offensive Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available offensive rebounds a player grabbed while they were on the floor." scope="col">ORB%</th> <th aria-label="Defensive Rebound Percentage" class="poptip center" data-stat="drb_pct" data-tip="&lt;b&gt;Defensive Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available defensive rebounds a player grabbed while they were on the floor." scope="col">DRB%</th> <th aria-label="Total Rebound Percentage" class="poptip center" data-stat="trb_pct" data-tip="&lt;b&gt;Total Rebound Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of available rebounds a player grabbed while they were on the floor." scope="col">TRB%</th> <th aria-label="Assist Percentage" class="poptip center" data-stat="ast_pct" data-tip="&lt;b&gt;Assist Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of teammate field goals a player assisted while they were on the floor." scope="col">AST%</th> <th aria-label="Steal Percentage" class="poptip center" data-stat="stl_pct" data-tip="&lt;b&gt;Steal Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of opponent possessions that end with a steal by the player while they were on the floor." scope="col">STL%</th> <th aria-label="Block Percentage" class="poptip center" data-stat="blk_pct" data-tip="&lt;b&gt;Block Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of opponent two-point field goal attempts blocked by the player while they were on the floor." scope="col">BLK%</th> <th aria-label="Turnover Percentage" class="poptip sort_default_asc center" data-stat="tov_pct" data-tip="&lt;b&gt;Turnover Percentage&lt;/b&gt;&lt;br&gt;An estimate of turnovers committed per 100 plays." scope="col">TOV%</th> <th aria-label="Usage Percentage" class="poptip center" data-stat="usg_pct" data-tip="&lt;b&gt;Usage Percentage&lt;/b&gt;&lt;br&gt;An estimate of the percentage of team plays used by a player while they were on the floo ...

# %%
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
#driver = webdriver.Chrome(executable_path='C:/path/to/chromedriver.exe')

# %%
#Code to initialize the chrome driver
driver = webdriver.Chrome()

#have the chrome browser issue a get request to googl
driver.get("http://www.google.com")

# %%
search_box = driver.find_element(By.NAME, "q")

# %%
search_button = driver.find_element(By.NAME, "btnK")

# %%
search_box.send_keys("Selenium")

# %%
search_button.click()

# %%
driver.find_element(By.NAME, "q").get_attribute("value")
# Out:
# 'Selenium'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys



#driver = webdriver.Chrome(executable_path='C:/path/to/chromedriver.exe')
#This is for you want the driver in a static place

driver = webdriver.Chrome()
#Initialize the chrome instance

driver.get("http://www.google.com")
#Issue a get request to the website


search_box = driver.find_element(By.NAME, "q")
#Search the webpage for an element called a, set it equal to search_box


driver.implicitly_wait(2)
#Tell the driver to not do anything for 2 seconds ( Why? It's because we need the search button to load in after some text is being put into the search box)

search_button = driver.find_element(By.NAME, "btnK")
#Find the element on the webpage called btnL


search_box.send_keys("Selenium")
#Mimic the keystrokes S E L E N I U M to the search box


search_button.click()
#Mimic a click of the button on the search_button element



driver.find_element(By.NAME, "q").get_attribute("value") # => "Selenium"
#Find the element on the webpage called q, and get the attribute value.

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(2)



driver.get("https://www.basketball-reference.com/teams/PHI/2022.html")
roster_table = driver.find_element(By.ID, "roster")
raw_html = roster_table.get_attribute('innerHTML')
print(roster_table.get_attribute('innerHTML'))
driver.close()
# Out:
#     <caption>Roster Table</caption>
#
#
#    <colgroup><col><col><col><col><col><col><col><col><col></colgroup>
#    <thead>
#       <tr>
#          <th aria-label="No." data-stat="number" scope="col" class=" poptip sort_default_asc center" data-tip="Uniform Number">No.</th>
#          <th aria-label="Player" data-stat="player" scope="col" class=" poptip sort_default_asc center">Player</th>
#          <th aria-label="Pos" data-stat="pos" scope="col" class=" poptip sort_default_asc center" data-tip="Position">Pos</th>
#          <th aria-label="Ht" data-stat="height" scope="col" class=" poptip sort_default_asc center" data-tip="Height">Ht</th>
#          <th aria-label="Wt" data-stat="weight" scope="col" class=" poptip sort_default_asc center" data-tip="Weight">Wt</th>
#          <th aria-label="Birth Date" data-stat="birth_date" scope="col" class=" poptip sort_default_asc center">Birth Date</th>
#          <th aria-label="&nbsp;" data-stat="birth_country" scope="col" class=" poptip center">&nbsp;</th>
#          <th aria-label="Exp" data-stat="years_experience" scope="col" class=" poptip sort_default_asc center" data-tip="Years experience in NBA/ABA (prior to this season)">Exp</th>
#          <th aria-label="College" data-stat="college" scope="col" class=" poptip sort_default_asc center">College</th>
#       </tr>
#       </thead>
# <tbody><tr data-row="0"><th scope="row" class="center " data-stat="number">20</th><td class="left " data-stat="player" csk="Niang,Georges"><a href="/players/n/niangge01.html">Georges Niang</a></td><td class="center " data-stat="pos" csk="4">PF</td><td class="right " data-stat="height" csk="79.0">6-7</td><td class="right " data-stat="weight">230</td><td class="left " data-stat="birth_date" csk="19930617">June 17, 1993</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="5">5</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=iowast">Iowa State</a></td></tr>
# <tr data-row="1"><th scope="row" class="center iz" data-stat="number">0</th><td class="left " data-stat="player" csk="Maxey,Tyrese"><a href="/players/m/maxeyty01.html">Tyrese Maxey</a></td><td class="center " data-stat="pos" csk="1">PG</td><td class="right " data-stat="height" csk="74.0">6-2</td><td class="right " data-stat="weight">200</td><td class="left " data-stat="birth_date" csk="20001104">November 4, 2000</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="1">1</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=kentucky">Kentucky</a></td></tr>
# <tr data-row="2"><th scope="row" class="center " data-stat="number">12</th><td class="left " data-stat="player" csk="Harris,Tobias"><a href="/players/h/harrito02.html">Tobias Harris</a></td><td class="center " data-stat="pos" csk="4">PF</td><td class="right " data-stat="height" csk="80.0">6-8</td><td class="right " data-stat="weight">226</td><td class="left " data-stat="birth_date" csk="19920715">July 15, 1992</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="10">10</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>
# <tr data-row="3"><th scope="row" class="center " data-stat="number">21</th><td class="left " data-stat="player" csk="Embiid,Joel"><a href="/players/e/embiijo01.html">Joel Embiid</a></td><td class="center " data-stat="pos" csk="5">C</td><td class="right " data-stat="height" csk="84.0">7-0</td><td class="right " data-stat="weight">280</td><td class="left " data-stat="birth_date" csk="19940316">March 16, 1994</td><td class="right " data-stat="birth_country"><span class="f-i f-cm" style="">cm</span></td><td class="right " data-stat="years_experience" csk="5">5</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=kansas">Kansas</a></td></tr>
# <tr data-row="4"><th scope="row" class="center " data-stat="number">30</th><td class="left " data-stat="player" csk="Korkmaz,Furkan"><a href="/players/k/korkmfu01.html">Furkan Korkmaz</a></td><td class="center " data-stat="pos" csk="2">SG</td><td class="right " data-stat="height" csk="79.0">6-7</td><td class="right " data-stat="weight">202</td><td class="left " data-stat="birth_date" csk="19970724">July 24, 1997</td><td class="right " data-stat="birth_country"><span class="f-i f-tr" style="">tr</span></td><td class="right " data-stat="years_experience" csk="4">4</td><td class="left iz" data-stat="college"></td></tr>
# <tr data-row="5"><th scope="row" class="center " data-stat="number">22</th><td class="left " data-stat="player" csk="Thybulle,Matisse"><a href="/players/t/thybuma01.html">Matisse Thybulle</a></td><td class="center " data-stat="pos" csk="2">SG</td><td class="right " data-stat="height" csk="77.0">6-5</td><td class="right " data-stat="weight">201</td><td class="left " data-stat="birth_date" csk="19970304">March 4, 1997</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="2">2</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=washington">Washington</a></td></tr>
# <tr data-row="6"><th scope="row" class="center " data-stat="number">14</th><td class="left " data-stat="player" csk="Green,Danny"><a href="/players/g/greenda02.html">Danny Green</a></td><td class="center " data-stat="pos" csk="3">SF</td><td class="right " data-stat="height" csk="78.0">6-6</td><td class="right " data-stat="weight">215</td><td class="left " data-stat="birth_date" csk="19870622">June 22, 1987</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="12">12</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=unc">UNC</a></td></tr>
# <tr data-row="7"><th scope="row" class="center " data-stat="number">7</th><td class="left " data-stat="player" csk="Joe,Isaiah"><a href="/players/j/joeis01.html">Isaiah Joe</a></td><td class="center " data-stat="pos" csk="2">SG</td><td class="right " data-stat="height" csk="76.0">6-4</td><td class="right " data-stat="weight">165</td><td class="left " data-stat="birth_date" csk="19990702">July 2, 1999</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="1">1</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=arkansas">Arkansas</a></td></tr>
# <tr data-row="8"><th scope="row" class="center " data-stat="number">18</th><td class="left " data-stat="player" csk="Milton,Shake"><a href="/players/m/miltosh01.html">Shake Milton</a></td><td class="center " data-stat="pos" csk="1">PG</td><td class="right " data-stat="height" csk="77.0">6-5</td><td class="right " data-stat="weight">205</td><td class="left " data-stat="birth_date" csk="19960926">September 26, 1996</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="3">3</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=smethodist">SMU</a></td></tr>
# <tr data-row="9"><th scope="row" class="center " data-stat="number">44</th><td class="left " data-stat="player" csk="Reed,Paul"><a href="/players/r/reedpa01.html">Paul Reed</a></td><td class="center " data-stat="pos" csk="5">C</td><td class="right " data-stat="height" csk="81.0">6-9</td><td class="right " data-stat="weight">210</td><td class="left " data-stat="birth_date" csk="19990614">June 14, 1999</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="1">1</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=depaul">DePaul</a></td></tr>
# <tr data-row="10"><th scope="row" class="center " data-stat="number">23</th><td class="left " data-stat="player" csk="Bassey,Charles"><a href="/players/b/bassech01.html">Charles Bassey</a></td><td class="center " data-stat="pos" csk="4">PF</td><td class="right " data-stat="height" csk="83.0">6-11</td><td class="right " data-stat="weight">235</td><td class="left " data-stat="birth_date" csk="20001028">October 28, 2000</td><td class="right " data-stat="birth_country"><span class="f-i f-ng" style="">ng</span></td><td class="right " data-stat="years_experience" csk="0.5">R</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=wkentucky">Western Kentucky</a></td></tr>
# <tr data-row="11"><th scope="row" class="center " data-stat="number">16</th><td class="left " data-stat="player" csk="Brown,Charlie"><a href="/players/b/brownch02.html">Charlie Brown Jr.</a></td><td class="center " data-stat="pos" csk="2">SG</td><td class="right " data-stat="height" csk="78.0">6-6</td><td class="right " data-stat="weight">199</td><td class="left " data-stat="birth_date" csk="19970202">February 2, 1997</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="2">2</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=stjosephs">Saint Joseph's</a></td></tr>
# <tr data-row="12"><th scope="row" class="center " data-stat="number">1</th><td class="left " data-stat="player" csk="Harden,James"><a href="/players/h/hardeja01.html">James Harden</a></td><td class="center " data-stat="pos" csk="2">SG</td><td class="right " data-stat="height" csk="77.0">6-5</td><td class="right " data-stat="weight">220</td><td class="left " data-stat="birth_date" csk="19890826">August 26, 1989</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="12">12</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=arizonast">Arizona State</a></td></tr>
# <tr data-row="13"><th scope="row" class="center " data-stat="number">5</th><td class="left " data-stat="player" csk="Powell,Myles"><a href="/players/p/powelmy01.html">Myles Powell</a>&nbsp;&nbsp;<span class="note"><small>(TW)</small></span></td><td class="center " data-stat="pos" csk="1">PG</td><td class="right " data-stat="height" csk="74.0">6-2</td><td class="right " data-stat="weight">195</td><td class="left " data-stat="birth_date" csk="19970707">July 7, 1997</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="0.5">R</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=setonhall">Seton Hall</a></td></tr>
# <tr data-row="14"><th scope="row" class="center " data-stat="number">8</th><td class="left " data-stat="player" csk="Millsap,Paul"><a href="/players/m/millspa01.html">Paul Millsap</a></td><td class="center " data-stat="pos" csk="4">PF</td><td class="right " data-stat="height" csk="79.0">6-7</td><td class="right " data-stat="weight">257</td><td class="left " data-stat="birth_date" csk="19850210">February 10, 1985</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="15">15</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=latech">Louisiana Tech</a></td></tr>
# <tr data-row="15"><th scope="row" class="center " data-stat="number">9</th><td class="left " data-stat="player" csk="Jordan,DeAndre"><a href="/players/j/jordade01.html">DeAndre Jordan</a></td><td class="center " data-stat="pos" csk="5">C</td><td class="right " data-stat="height" csk="83.0">6-11</td><td class="right " data-stat="weight">265</td><td class="left " data-stat="birth_date" csk="19880721">July 21, 1988</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="13">13</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=texasam">Texas A&amp;M</a></td></tr>
# <tr data-row="16"><th scope="row" class="center " data-stat="number">11</th><td class="left " data-stat="player" csk="Springer,Jaden"><a href="/players/s/sprinja01.html">Jaden Springer</a></td><td class="center " data-stat="pos" csk="2">SG</td><td class="right " data-stat="height" csk="76.0">6-4</td><td class="right " data-stat="weight">204</td><td class="left " data-stat="birth_date" csk="20020925">September 25, 2002</td><td class="right " data-stat="birth_country"><span class="f-i f-us" style="">us</span></td><td class="right " data-stat="years_experience" csk="0.5">R</td><td class="left " data-stat="college"><a href="/friv/colleges.fcgi?college=tennessee">Tennessee</a></td></tr>
#
# </tbody>

# %%
soup = BeautifulSoup(raw_html,'html.parser')

# %%
all_rows = soup.findAll('tr')

# %%
del all_rows[0]

# %%
player_dict = []
player_list = []
keys = ['Player_Name','Position','Height','Weight','DOB','COB','Number','Alma_Matter']
for player in all_rows:
    found_rows= player.find_all('td')
    stripped_text = [ele.text for ele in found_rows]
    player_dict.append(dict(zip(keys,stripped_text)))


player_dict
# Out:
# [{'Player_Name': 'Georges Niang',
#   'Position': 'PF',
#   'Height': '6-7',
#   'Weight': '230',
#   'DOB': 'June 17, 1993',
#   'COB': 'us',
#   'Number': '5',
#   'Alma_Matter': 'Iowa State'},
#  {'Player_Name': 'Tyrese Maxey',
#   'Position': 'PG',
#   'Height': '6-2',
#   'Weight': '200',
#   'DOB': 'November 4, 2000',
#   'COB': 'us',
#   'Number': '1',
#   'Alma_Matter': 'Kentucky'},
#  {'Player_Name': 'Tobias Harris',
#   'Position': 'PF',
#   'Height': '6-8',
#   'Weight': '226',
#   'DOB': 'July 15, 1992',
#   'COB': 'us',
#   'Number': '10',
#   'Alma_Matter': 'Tennessee'},
#  {'Player_Name': 'Joel Embiid',
#   'Position': 'C',
#   'Height': '7-0',
#   'Weight': '280',
#   'DOB': 'March 16, 1994',
#   'COB': 'cm',
#   'Number': '5',
#   'Alma_Matter': 'Kansas'},
#  {'Player_Name': 'Furkan Korkmaz',
#   'Position': 'SG',
#   'Height': '6-7',
#   'Weight': '202',
#   'DOB': 'July 24, 1997',
#   'COB': 'tr',
#   'Number': '4',
#   'Alma_Matter': ''},
#  {'Player_Name': 'Matisse Thybulle',
#   'Position': 'SG',
#   'Height': '6-5',
#   'Weight': '201',
#   'DOB': 'March 4, 1997',
#   'COB': 'us',
#   'Number': '2',
#   'Alma_Matter': 'Washington'},
#  {'Player_Name': 'Danny Green',
#   'Position': 'SF',
#   'Height': '6-6',
#   'Weight': '215',
#   'DOB': 'June 22, 1987',
#   'COB': 'us',
#   'Number': '12',
#   'Alma_Matter': 'UNC'},
#  {'Player_Name': 'Isaiah Joe',
#   'Position': 'SG',
#   'Height': '6-4',
#   'Weight': '165',
#   'DOB': 'July 2, 1999',
#   'COB': 'us',
#   'Number': '1',
#   'Alma_Matter': 'Arkansas'},
#  {'Player_Name': 'Shake Milton',
#   'Position': 'PG',
#   'Height': '6-5',
#   'Weight': '205',
#   'DOB': 'September 26, 1996',
#   'COB': 'us',
#   'Number': '3',
#   'Alma_Matter': 'SMU'},
#  {'Player_Name': 'Paul Reed',
#   'Position': 'C',
#   'Height': '6-9',
#   'Weight': '210',
#   'DOB': 'June 14, 1999',
#   'COB': 'us',
#   'Number': '1',
#   'Alma_Matter': 'DePaul'},
#  {'Player_Name': 'Charles Bassey',
#   'Position': 'PF',
#   'Height': '6-11',
#   'Weight': '235',
#   'DOB': 'October 28, 2000',
#   'COB': 'ng',
#   'Number': 'R',
#   'Alma_Matter': 'Western Kentucky'},
#  {'Player_Name': 'Charlie Brown Jr.',
#   'Position': 'SG',
#   'Height': '6-6',
#   'Weight': '199',
#   'DOB': 'February 2, 1997',
#   'COB': 'us',
#   'Number': '2',
#   'Alma_Matter': "Saint Joseph's"},
#  {'Player_Name': 'James Harden',
#   'Position': 'SG',
#   'Height': '6-5',
#   'Weight': '220',
#   'DOB': 'August 26, 1989',
#   'COB': 'us',
#   'Number': '12',
#   'Alma_Matter': 'Arizona State'},
#  {'Player_Name': 'Myles Powell\xa0\xa0(TW)',
#   'Position': 'PG',
#   'Height': '6-2',
#   'Weight': '195',
#   'DOB': 'July 7, 1997',
#   'COB': 'us',
#   'Number': 'R',
#   'Alma_Matter': 'Seton Hall'},
#  {'Player_Name': 'Paul Millsap',
#   'Position': 'PF',
#   'Height': '6-7',
#   'Weight': '257',
#   'DOB': 'February 10, 1985',
#   'COB': 'us',
#   'Number': '15',
#   'Alma_Matter': 'Louisiana Tech'},
#  {'Player_Name': 'DeAndre Jordan',
#   'Position': 'C',
#   'Height': '6-11',
#   'Weight': '265',
#   'DOB': 'July 21, 1988',
#   'COB': 'us',
#   'Number': '13',
#   'Alma_Matter': 'Texas A&M'},
#  {'Player_Name': 'Jaden Springer',
#   'Position': 'SG',
#   'Height': '6-4',
#   'Weight': '204',
#   'DOB': 'September 25, 2002',
#   'COB': 'us',
#   'Number': 'R',
#   'Alma_Matter': 'Tennessee'}]

# %%
df = pd.DataFrame(player_dict)

# %%
df
# Out:
#            Player_Name Position Height Weight                 DOB COB Number  \
# 0        Georges Niang       PF    6-7    230       June 17, 1993  us      5
# 1         Tyrese Maxey       PG    6-2    200    November 4, 2000  us      1
# 2        Tobias Harris       PF    6-8    226       July 15, 1992  us     10
# 3          Joel Embiid        C    7-0    280      March 16, 1994  cm      5
# 4       Furkan Korkmaz       SG    6-7    202       July 24, 1997  tr      4
# 5     Matisse Thybulle       SG    6-5    201       March 4, 1997  us      2
# 6          Danny Green       SF    6-6    215       June 22, 1987  us     12
# 7           Isaiah Joe       SG    6-4    165        July 2, 1999  us      1
# 8         Shake Milton       PG    6-5    205  September 26, 1996  us      3
# 9            Paul Reed        C    6-9    210       June 14, 1999  us      1
# 10      Charles Bassey       PF   6-11    235    October 28, 2000  ng      R
# 11   Charlie Brown Jr.       SG    6-6    199    February 2, 1997  us      2
# 12        James Harden       SG    6-5    220     August 26, 1989  us     12
# 13  Myles Powell  (TW)       PG    6-2    195        July 7, 1997  us      R
# 14        Paul Millsap       PF    6-7    257   February 10, 1985  us     15
# 15      DeAndre Jordan        C   6-11    265       July 21, 1988  us     13
# 16      Jaden Springer       SG    6-4    204  September 25, 2002  us      R
#
#          Alma_Matter
# 0         Iowa State
# 1           Kentucky
# 2          Tennessee
# 3             Kansas
# 4
# 5         Washington
# 6                UNC
# 7           Arkansas
# 8                SMU
# 9             DePaul
# 10  Western Kentucky
# 11    Saint Joseph's
# 12     Arizona State
# 13        Seton Hall
# 14    Louisiana Tech
# 15         Texas A&M
# 16         Tennessee

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(2)



driver.get("https://www.basketball-reference.com/teams/PHI/2022.html")
salaries_table = driver.find_element(By.ID, "salaries2")
raw_html = salaries_table.get_attribute('innerHTML')
print(salaries_table.get_attribute('innerHTML'))
driver.close()
# Out:
#     <caption>Salaries Table</caption>
#
#
#    <colgroup><col><col><col></colgroup>
#    <thead>
#       <tr>
#          <th aria-label="Rk" data-stat="ranker" scope="col" class="ranker poptip sort_default_asc show_partial_when_sorting center" data-tip="Rank">Rk</th>
#          <th aria-label="&nbsp;" data-stat="player" scope="col" class=" poptip sort_default_asc center">&nbsp;</th>
#          <th aria-label="Salary" data-stat="salary" scope="col" class=" poptip right">Salary</th>
#       </tr>
#       </thead>
# <tbody><tr><th scope="row" class="center " data-stat="ranker" csk="1">1</th><td class="left " data-stat="player"><a href="/players/h/hardeja01.html">James Harden</a></td><td class="right " data-stat="salary" csk="43848000">$43,848,000</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="2">2</th><td class="left " data-stat="player"><a href="/players/h/harrito02.html">Tobias Harris</a></td><td class="right " data-stat="salary" csk="36000000">$36,000,000</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="3">3</th><td class="left " data-stat="player"><a href="/players/e/embiijo01.html">Joel Embiid</a></td><td class="right " data-stat="salary" csk="31579390">$31,579,390</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="4">4</th><td class="left " data-stat="player"><a href="/players/g/greenda02.html">Danny Green</a></td><td class="right " data-stat="salary" csk="10000000">$10,000,000</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="5">5</th><td class="left " data-stat="player"><a href="/players/k/korkmfu01.html">Furkan Korkmaz</a></td><td class="right " data-stat="salary" csk="4629630">$4,629,630</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="6">6</th><td class="left " data-stat="player"><a href="/players/n/niangge01.html">Georges Niang</a></td><td class="right " data-stat="salary" csk="3300000">$3,300,000</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="7">7</th><td class="left " data-stat="player"><a href="/players/t/thybuma01.html">Matisse Thybulle</a></td><td class="right " data-stat="salary" csk="2840160">$2,840,160</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="8">8</th><td class="left " data-stat="player"><a href="/players/m/millspa01.html">Paul Millsap</a></td><td class="right " data-stat="salary" csk="2641691">$2,641,691</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="9">9</th><td class="left " data-stat="player"><a href="/players/m/maxeyty01.html">Tyrese Maxey</a></td><td class="right " data-stat="salary" csk="2602920">$2,602,920</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="10">10</th><td class="left " data-stat="player"><a href="/players/s/sprinja01.html">Jaden Springer</a></td><td class="right " data-stat="salary" csk="2023800">$2,023,800</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="11">11</th><td class="left " data-stat="player"><a href="/players/m/miltosh01.html">Shake Milton</a></td><td class="right " data-stat="salary" csk="1846738">$1,846,738</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="12">12</th><td class="left " data-stat="player"><a href="/players/j/joeis01.html">Isaiah Joe</a></td><td class="right " data-stat="salary" csk="1517981">$1,517,981</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="13">13</th><td class="left " data-stat="player"><a href="/players/r/reedpa01.html">Paul Reed</a></td><td class="right " data-stat="salary" csk="1517981">$1,517,981</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="14">14</th><td class="left " data-stat="player"><a href="/players/h/hillge01.html">George Hill</a></td><td class="right " data-stat="salary" csk="1275491">$1,275,491</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="15">15</th><td class="left " data-stat="player"><a href="/players/b/bassech01.html">Charles Bassey</a></td><td class="right " data-stat="salary" csk="925258">$925,258</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="16">16</th><td class="left " data-stat="player"><a href="/players/j/jordade01.html">DeAndre Jordan</a></td><td class="right " data-stat="salary" csk="592103">$592,103</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="17">17</th><td class="left " data-stat="player"><a href="/players/j/johnsty01.html">Tyler Johnson</a></td><td class="right " data-stat="salary" csk="128709">$128,709</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="18">18</th><td class="left " data-stat="player"><a href="/players/c/caulewi01.html">Willie Cauley-Stein</a></td><td class="right " data-stat="salary" csk="120083">$120,083</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="19">19</th><td class="left " data-stat="player"><a href="/players/b/brownch02.html">Charlie Brown Jr.</a></td><td class="right " data-stat="salary" csk="95930">$95,930</td></tr>
# <tr><th scope="row" class="center " data-stat="ranker" csk="20">20</th><td class="left " data-stat="player"><a href="/players/k/keybr01.html">Braxton Key</a></td><td class="right " data-stat="salary" csk="53176">$53,176</td></tr>
#
# </tbody>

# %%
soup = BeautifulSoup(raw_html,'html.parser')

# %%
player_salaries = soup.findAll('tr')

# %%
del player_salaries[0]

# %%
player_salaries
# Out:
# [<tr><th class="center" csk="1" data-stat="ranker" scope="row">1</th><td class="left" data-stat="player"><a href="/players/h/hardeja01.html">James Harden</a></td><td class="right" csk="43848000" data-stat="salary">$43,848,000</td></tr>,
#  <tr><th class="center" csk="2" data-stat="ranker" scope="row">2</th><td class="left" data-stat="player"><a href="/players/h/harrito02.html">Tobias Harris</a></td><td class="right" csk="36000000" data-stat="salary">$36,000,000</td></tr>,
#  <tr><th class="center" csk="3" data-stat="ranker" scope="row">3</th><td class="left" data-stat="player"><a href="/players/e/embiijo01.html">Joel Embiid</a></td><td class="right" csk="31579390" data-stat="salary">$31,579,390</td></tr>,
#  <tr><th class="center" csk="4" data-stat="ranker" scope="row">4</th><td class="left" data-stat="player"><a href="/players/g/greenda02.html">Danny Green</a></td><td class="right" csk="10000000" data-stat="salary">$10,000,000</td></tr>,
#  <tr><th class="center" csk="5" data-stat="ranker" scope="row">5</th><td class="left" data-stat="player"><a href="/players/k/korkmfu01.html">Furkan Korkmaz</a></td><td class="right" csk="4629630" data-stat="salary">$4,629,630</td></tr>,
#  <tr><th class="center" csk="6" data-stat="ranker" scope="row">6</th><td class="left" data-stat="player"><a href="/players/n/niangge01.html">Georges Niang</a></td><td class="right" csk="3300000" data-stat="salary">$3,300,000</td></tr>,
#  <tr><th class="center" csk="7" data-stat="ranker" scope="row">7</th><td class="left" data-stat="player"><a href="/players/t/thybuma01.html">Matisse Thybulle</a></td><td class="right" csk="2840160" data-stat="salary">$2,840,160</td></tr>,
#  <tr><th class="center" csk="8" data-stat="ranker" scope="row">8</th><td class="left" data-stat="player"><a href="/players/m/millspa01.html">Paul Millsap</a></td><td class="right" csk="2641691" data-stat="salary">$2,641,691</td></tr>,
#  <tr><th class="center" csk="9" data-stat="ranker" scope="row">9</th><td class="left" data-stat="player"><a href="/players/m/maxeyty01.html">Tyrese Maxey</a></td><td class="right" csk="2602920" data-stat="salary">$2,602,920</td></tr>,
#  <tr><th class="center" csk="10" data-stat="ranker" scope="row">10</th><td class="left" data-stat="player"><a href="/players/s/sprinja01.html">Jaden Springer</a></td><td class="right" csk="2023800" data-stat="salary">$2,023,800</td></tr>,
#  <tr><th class="center" csk="11" data-stat="ranker" scope="row">11</th><td class="left" data-stat="player"><a href="/players/m/miltosh01.html">Shake Milton</a></td><td class="right" csk="1846738" data-stat="salary">$1,846,738</td></tr>,
#  <tr><th class="center" csk="12" data-stat="ranker" scope="row">12</th><td class="left" data-stat="player"><a href="/players/j/joeis01.html">Isaiah Joe</a></td><td class="right" csk="1517981" data-stat="salary">$1,517,981</td></tr>,
#  <tr><th class="center" csk="13" data-stat="ranker" scope="row">13</th><td class="left" data-stat="player"><a href="/players/r/reedpa01.html">Paul Reed</a></td><td class="right" csk="1517981" data-stat="salary">$1,517,981</td></tr>,
#  <tr><th class="center" csk="14" data-stat="ranker" scope="row">14</th><td class="left" data-stat="player"><a href="/players/h/hillge01.html">George Hill</a></td><td class="right" csk="1275491" data-stat="salary">$1,275,491</td></tr>,
#  <tr><th class="center" csk="15" data-stat="ranker" scope="row">15</th><td class="left" data-stat="player"><a href="/players/b/bassech01.html">Charles Bassey</a></td><td class="right" csk="925258" data-stat="salary">$925,258</td></tr>,
#  <tr><th class="center" csk="16" data-stat="ranker" scope="row">16</th><td class="left" data-stat="player"><a href="/players/j/jordade01.html">DeAndre Jordan</a></td><td class="right" csk="592103" data-stat="salary">$592,103</td></tr>,
#  <tr><th class="center" csk="17" data-stat="ranker" scope="row">17</th><td class="left" data-stat="player"><a href="/players/j/johnsty01.html">Tyler Johnson</a></td><td class="right" csk="128709" data-stat="salary">$128,709</td></tr>,
#  <tr><th class="center" csk="18" data-stat="ranker" scope="row">18</th><td class="left" data-stat="player"><a href="/players/c/caulewi01.html">Willie Cauley-Stein</a></td><td class="right" csk="120083" data-stat="salary">$120,083</td></tr>,
#  <tr><th class="center" csk="19" data-stat="ranker" scope="row">19</th><td class="left" data-stat="player"><a href="/players/b/brownch02.html">Charlie Brown Jr.</a></td><td class="right" csk="95930" data-stat="salary">$95,930</td></tr>,
#  <tr><th class="center" csk="20" data-stat="ranker" scope="row">20</th><td class="left" data-stat="player"><a href="/players/k/keybr01.html">Braxton Key</a></td><td class="right" csk="53176" data-stat="salary">$53,176</td></tr>]

# %%
player_salaries_list = []
for player in player_salaries:
    found_rows= player.find_all('td')
    stripped_text = [ele.text for ele in found_rows]
    player_salaries_list.append(stripped_text)

# %%
player_salaries_list
# Out:
# [['James Harden', '$43,848,000'],
#  ['Tobias Harris', '$36,000,000'],
#  ['Joel Embiid', '$31,579,390'],
#  ['Danny Green', '$10,000,000'],
#  ['Furkan Korkmaz', '$4,629,630'],
#  ['Georges Niang', '$3,300,000'],
#  ['Matisse Thybulle', '$2,840,160'],
#  ['Paul Millsap', '$2,641,691'],
#  ['Tyrese Maxey', '$2,602,920'],
#  ['Jaden Springer', '$2,023,800'],
#  ['Shake Milton', '$1,846,738'],
#  ['Isaiah Joe', '$1,517,981'],
#  ['Paul Reed', '$1,517,981'],
#  ['George Hill', '$1,275,491'],
#  ['Charles Bassey', '$925,258'],
#  ['DeAndre Jordan', '$592,103'],
#  ['Tyler Johnson', '$128,709'],
#  ['Willie Cauley-Stein', '$120,083'],
#  ['Charlie Brown Jr.', '$95,930'],
#  ['Braxton Key', '$53,176']]
